# %% [markdown]
# ## Connect to Chicago Data Portal API - Business Licenses Data

# %%
#Import dependencies
import pandas as pd
import requests
import json

# Google developer API key
from config2 import API_chi_key

# %%
# Build API URL
target_URL = f"https://data.cityofchicago.org/resource/xqx5-8hwx.json?$$app_token={API_chi_key}&zip_code="

# %%
# create list of zipcodes we are examining based
# on three different businesses of interest
zipcodes = ["60610","60607","60606","60661",
            "60614","60622","60647","60654"]

# %%
# Create a request to get json data on business licences
responses = []
for zipcode in zipcodes:
    license_response = requests.get(target_URL + zipcode).json()
    responses.append(license_response)

# %%
# Create sepearte variables for the 8 responses for zipcodes
# Data loaded in nested gropus based on zipcodes, so
# needed to make them separate
zip_60610 = responses[0]
zip_60607 = responses[1]
zip_60606 = responses[2]
zip_60661 = responses[3]
zip_60614 = responses[4]
zip_60622 = responses[5]
zip_60647 = responses[6]
zip_60654 = responses[7]

# %%
# Read zipcode_responses_busi.json files into pd DF
zip_60610_data = pd.DataFrame(zip_60610)

# %%
# Create list of the json object variables
# excluding zip_60610 bc that will start as a DF
zip_data = [zip_60607, zip_60606, zip_60661, zip_60614,
           zip_60622, zip_60647, zip_60654]

# %%
# Create a new DF to save compiled business data into
all_7_zipcodes = zip_60610_data

# %%
# Append json objects to all_7_zipcode DF
# Print length of all_7_zipcode to check adding correctly
for zipcodes_df in zip_data:
    all_7_zipcodes = all_7_zipcodes.append(zipcodes_df)
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
# Get list of headers of all_7_zipcodes
list(all_7_zipcodes)
# Out:
# ['account_number',
#  'address',
#  'application_created_date',
#  'application_requirements_complete',
#  'application_type',
#  'business_activity',
#  'business_activity_id',
#  'city',
#  'conditional_approval',
#  'date_issued',
#  'doing_business_as_name',
#  'expiration_date',
#  'id',
#  'latitude',
#  'legal_name',
#  'license_approved_for_issuance',
#  'license_code',
#  'license_description',
#  'license_id',
#  'license_number',
#  'license_start_date',
#  'license_status',
#  'license_status_change_date',
#  'location',
#  'longitude',
#  'payment_date',
#  'police_district',
#  'precinct',
#  'site_number',
#  'ssa',
#  'state',
#  'ward',
#  'ward_precinct',
#  'zip_code']

# %%
# Select certain columns to show 
core_info_busi_licences = all_7_zipcodes[['legal_name', 'doing_business_as_name',
                                        'zip_code', 'license_description', 
                                        'business_activity', 'application_type', 
                                        'license_start_date', 'latitude', 'longitude']]

# %%
# Get an idea of the number of null values in each column
core_info_busi_licences.isna().sum()
# Out:
# legal_name                   0
# doing_business_as_name       0
# zip_code                     0
# license_description          0
# business_activity         1541
# application_type             0
# license_start_date          16
# latitude                   423
# longitude                  423
# dtype: int64

# %%
# Add sepearate column for just the start year
# Will use later when selecting year businesess were created
core_info_busi_licences['start_year'] = core_info_busi_licences['license_start_date']
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# ['legal_name',
#  'doing_business_as_name',
#  'zip_code',
#  'license_description',
#  'business_activity',
#  'application_type',
#  'license_start_date',
#  'latitude',
#  'longitude',
#  'start_year']

# %%
# Edit 'start_year' to just include year from date information
core_info_busi_licences['start_year'] = core_info_busi_licences['start_year'].str[0:4]
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Explore what kinds of businesses are missing "latitude" and "longitude"
# Also, the 'business_activity' licenses have null values (limited Business Licences?)
core_info_busi_licences[core_info_busi_licences.isnull().any(axis=1)]
# Out:
#                                             legal_name  \
# 15                                  PAPER SOURCE, INC.
# 26                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 32                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 35                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 54                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 63                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 72                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 76                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 77                   DAVE & BUSTER'S OF ILLINOIS, INC.
# 78                            H & S TRAVEL GROUP, INC.
# 83                 CHICAGO FLY FISHING OUTFITTERS LTD.
# 89                                       SOOK CHA CHOI
# 92                              JOEL OPPENHEIMER, INC.
# 122                                  STUDIO BLUE, INC.
# 128                                1028 N RUSH ST CORP
# 134                                    WAKENYA CHISLEY
# 135                                     CASSIDY OBRIEN
# 136                               ELLIE VAN KEIRSBILCK
# 147                                       PAMELA NOSSE
# 161                   CHICAGO HEALTH ENTERPRISES, LTD.
# 190              FEDEX OFFICE AND PRINT SERVICES, INC.
# 191                CHESTNUT MARC VENTURE OPERATING LLC
# 192              FEDEX OFFICE AND PRINT SERVICES, INC.
# 193                CHESTNUT MARC VENTURE OPERATING LLC
# 195                                 KCL FITNESS L.L.C.
# 229                                        RUBEN REYES
# 236         WEARY & BAITY INC. DBA THE UPS STORE #2872
# 245                                 POTASH BROS., INC.
# 248                                 POTASH BROS., INC.
# 260                                 POTASH BROS., INC.
# ..                                                 ...
# 801                  RESPONSIBLE INVESTMENT GROUP, LLC
# 804                                 OFFICE DEPOT, INC.
# 812                  RESPONSIBLE INVESTMENT GROUP, LLC
# 823                                       RACHAEL HILL
# 831                               SPOTVIEW CORPORATION
# 832                         The Power Company USA, LLC
# 834                         The Power Company USA, LLC
# 859                                    CLEISE SPA INC.
# 864                                        AMBER BAUER
# 871                        NORTHERN LIGHTS DIRECT LTD.
# 878                                        KELLI EAGAN
# 888                               YOUNG & RUBICAM INC.
# 889                      STARCOM MEDIAVEST GROUP, INC.
# 895                                THE AUTO CLUB GROUP
# 904  INTERNATIONAL ASSOCIATION OF LIGHTING DESIGNER...
# 911                    632 N. DEARBORN OPERATIONS, LLC
# 913                    632 N. DEARBORN OPERATIONS, LLC
# 943                    632 N. DEARBORN OPERATIONS, LLC
# 947                    632 N. DEARBORN OPERATIONS, LLC
# 950                    632 N. DEARBORN OPERATIONS, LLC
# 958                    632 N. DEARBORN OPERATIONS, LLC
# 960                    632 N. DEARBORN OPERATIONS, LLC
# 963                    632 N. DEARBORN OPERATIONS, LLC
# 964                    632 N. DEARBORN OPERATIONS, LLC
# 977                                UCG ASSOCIATES, INC
# 979                        REGUS MANAGEMENT GROUP LLC.
# 981                    632 N. DEARBORN OPERATIONS, LLC
# 982                    632 N. DEARBORN OPERATIONS, LLC
# 992                    632 N. DEARBORN OPERATIONS, LLC
# 994                    632 N. DEARBORN OPERATIONS, LLC
#
#                                 doing_business_as_name zip_code  \
# 15                                    PAPER SOURCE INC    60610
# 26                                     DAVE & BUSTER'S    60610
# 32                                     DAVE & BUSTER'S    60610
# 35                                     DAVE & BUSTER'S    60610
# 54                                     DAVE & BUSTER'S    60610
# 63                                     DAVE & BUSTER'S    60610
# 72                                     DAVE & BUSTER'S    60610
# 76                                     DAVE & BUSTER'S    60610
# 77                                     DAVE & BUSTER'S    60610
# 78   FOREMOST TRAVEL & TOURS/TRAVELONI/WINDY CITY T...    60610
# 83                 CHICAGO FLY FISHING OUTFITTERS LTD.    60610
# 89                                       BEST CLEANERS    60610
# 92                               JOEL OPPENHEIMER, INC    60610
# 122                                        STUDIO BLUE    60610
# 128                                GIBSON'S STEAKHOUSE    60610
# 134                                    WAKENYA CHISLEY    60610
# 135                                     CASSIDY OBRIEN    60610
# 136                               ELLIE VAN KEIRSBILCK    60610
# 147                                       PAMELA NOSSE    60610
# 161                      CHICAGO HEALTH - MAPLE STREET    60610
# 190                  FEDEX OFFICE AND PRINT SVCS, INC.    60610
# 191                                   FIELDHOUSE JONES    60610
# 192                  FEDEX OFFICE AND PRINT SVCS, INC.    60610
# 193                                   FIELDHOUSE JONES    60610
# 195                              WELLS STREET CROSSFIT    60610
# 229                                        RUBEN REYES    60610
# 236                                THE UPS STORE #2872    60610
# 245                                    POTASH BROS INC    60610
# 248                                    POTASH BROS INC    60610
# 260                                    POTASH BROS INC    60610
# ..                                                 ...      ...
# 801                                      LPL FINANCIAL    60654
# 804                                       OFFICE DEPOT    60654
# 812                                      LPL FINANCIAL    60654
# 823                                       RACHAEL HILL    60654
# 831                                 PARAMOUNT CLEANERS    60654
# 832                                  The Power Company    60654
# 834                                  The Power Company    60654
# 859                           CLEISE BRAZILIAN DAY SPA    60654
# 864                                        AMBER BAUER    60654
# 871                        NORTHERN LIGHTS DIRECT LTD.    60654
# 878                                        KELLI EAGAN    60654
# 888                                  BURSON-MARSTELLER    60654
# 889                                      SPARK FOUNDRY    60654
# 895                                        AAA CHICAGO    60654
# 904    INTERNATIONAL ASSOCIATION OF LIGHTING DESIGNERS    60654
# 911                                        TAO CHICAGO    60654
# 913                                        TAO CHICAGO    60654
# 943                                        TAO CHICAGO    60654
# 947                                        TAO CHICAGO    60654
# 950                                        TAO CHICAGO    60654
# 958                                        TAO CHICAGO    60654
# 960                                        TAO CHICAGO    60654
# 963                                        TAO CHICAGO    60654
# 964                                        TAO CHICAGO    60654
# 977                               UCG ASSOCIATES, INC.    60654
# 979                         Regus Management Group LLC    60654
# 981                                        TAO CHICAGO    60654
# 982                                        TAO CHICAGO    60654
# 992                                        TAO CHICAGO    60654
# 994                                        TAO CHICAGO    60654
#
#                license_description  \
# 15        Limited Business License
# 26        Limited Business License
# 32        Limited Business License
# 35        Limited Business License
# 54        Limited Business License
# 63        Limited Business License
# 72        Limited Business License
# 76        Limited Business License
# 77        Limited Business License
# 78        Limited Business License
# 83        Limited Business License
# 89        Limited Business License
# 92        Limited Business License
# 122       Limited Business License
# 128       Limited Business License
# 134  Pharmaceutical Representative
# 135  Pharmaceutical Representative
# 136  Pharmaceutical Representative
# 147  Pharmaceutical Representative
# 161       Limited Business License
# 190       Limited Business License
# 191      Retail Food Establishment
# 192       Limited Business License
# 193     Regulated Business License
# 195     Regulated Business License
# 229  Pharmaceutical Representative
# 236       Limited Business License
# 245       Limited Business License
# 248       Limited Business License
# 260       Limited Business License
# ..                             ...
# 801       Limited Business License
# 804       Limited Business License
# 812       Limited Business License
# 823  Pharmaceutical Representative
# 831       Limited Business License
# 832       Limited Business License
# 834       Limited Business License
# 859       Limited Business License
# 864  Pharmaceutical Representative
# 871       Limited Business License
# 878  Pharmaceutical Representative
# 888       Limited Business License
# 889       Limited Business License
# 895       Limited Business License
# 904       Limited Business License
# 911    Tobacco Vending, Individual
# 913    Tobacco Vending, Individual
# 943    Tobacco Vending, Individual
# 947    Tobacco Vending, Individual
# 950       Limited Business License
# 958    Tobacco Vending, Individual
# 960       Limited Business License
# 963       Limited Business License
# 964       Limited Business License
# 977       Limited Business License
# 979       Limited Business License
# 981       Limited Business License
# 982    Tobacco Vending, Individual
# 992    Tobacco Vending, Individual
# 994       Limited Business License
#
#                                      business_activity application_type  \
# 15                                                 NaN            RENEW
# 26                                                 NaN            RENEW
# 32                                                 NaN            RENEW
# 35                                                 NaN            RENEW
# 54                                                 NaN            RENEW
# 63                                                 NaN            RENEW
# 72                                                 NaN            RENEW
# 76                                                 NaN            RENEW
# 77                                                 NaN            RENEW
# 78                                                 NaN            ISSUE
# 83                                                 NaN            RENEW
# 89                                                 NaN            RENEW
# 92                                                 NaN            RENEW
# 122                                                NaN            RENEW
# 128                                                NaN            RENEW
# 134  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 135  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 136  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 147  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 161                                                NaN            ISSUE
# 190                                                NaN            RENEW
# 191  Preparation of Food and Dining on Premise With...            RENEW
# 192                                                NaN            RENEW
# 193                   Hotel - 7 or More Sleeping Rooms            RENEW
# 195                                    Fitness Classes            RENEW
# 229  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 236                                                NaN            RENEW
# 245                                                NaN            RENEW
# 248                                                NaN            RENEW
# 260                                                NaN            RENEW
# ..                                                 ...              ...
# 801                                                NaN            RENEW
# 804                                                NaN            RENEW
# 812                                                NaN            RENEW
# 823  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 831                                                NaN            RENEW
# 832                                                NaN            RENEW
# 834                                                NaN            ISSUE
# 859                                                NaN            ISSUE
# 864  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 871                                                NaN            RENEW
# 878  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 888                                                NaN            RENEW
# 889                                                NaN            RENEW
# 895                                                NaN            RENEW
# 904                                                NaN            RENEW
# 911                                                NaN            RENEW
# 913                                                NaN            RENEW
# 943                                                NaN            RENEW
# 947                                                NaN            RENEW
# 950                                                NaN            RENEW
# 958                                                NaN            RENEW
# 960                                                NaN            RENEW
# 963                                                NaN            RENEW
# 964                                                NaN            RENEW
# 977                                                NaN            RENEW
# 979                                                NaN            RENEW
# 981                                                NaN            RENEW
# 982                                                NaN            RENEW
# 992                                                NaN            RENEW
# 994                                                NaN            RENEW
#
#           license_start_date      latitude      longitude start_year
# 15   2018-02-16T00:00:00.000  41.896692555  -87.635628437       2018
# 26   2011-03-16T00:00:00.000  41.901531983  -87.631526068       2011
# 32   2005-05-16T00:00:00.000  41.901531983  -87.631526068       2005
# 35   2003-05-16T00:00:00.000  41.901531983  -87.631526068       2003
# 54   2002-05-16T00:00:00.000  41.901531983  -87.631526068       2002
# 63   2009-03-16T00:00:00.000  41.901531983  -87.631526068       2009
# 72   2006-05-16T00:00:00.000  41.901531983  -87.631526068       2006
# 76   2007-05-16T00:00:00.000  41.901531983  -87.631526068       2007
# 77   2004-05-16T00:00:00.000  41.901531983  -87.631526068       2004
# 78   2012-11-05T00:00:00.000  41.907401025   -87.63445142       2012
# 83   2019-04-16T00:00:00.000  41.905391727  -87.641615883       2019
# 89   2018-02-16T00:00:00.000  41.903761516  -87.633306964       2018
# 92   2019-03-16T00:00:00.000  41.890156071  -87.629151995       2019
# 122  2002-02-16T00:00:00.000  41.889949311  -87.628373571       2002
# 128  2019-03-16T00:00:00.000  41.901867357  -87.628492145       2019
# 134  2018-12-18T00:00:00.000           NaN            NaN       2018
# 135  2019-01-28T00:00:00.000           NaN            NaN       2019
# 136  2018-11-08T00:00:00.000           NaN            NaN       2018
# 147  2019-02-16T00:00:00.000           NaN            NaN       2019
# 161  2010-11-10T00:00:00.000  41.901982552  -87.629263103       2010
# 190  2019-01-16T00:00:00.000  41.890526116  -87.634188858       2019
# 191  2018-11-16T00:00:00.000           NaN            NaN       2018
# 192  2019-01-16T00:00:00.000  41.904019547  -87.629841921       2019
# 193  2018-11-16T00:00:00.000           NaN            NaN       2018
# 195  2018-12-16T00:00:00.000           NaN            NaN       2018
# 229  2019-01-16T00:00:00.000           NaN            NaN       2019
# 236  2019-02-16T00:00:00.000  41.911013149  -87.638017712       2019
# 245  2007-02-16T00:00:00.000  41.898878197  -87.628111148       2007
# 248  2002-05-16T00:00:00.000  41.898878197  -87.628111148       2002
# 260  2004-05-16T00:00:00.000  41.898878197  -87.628111148       2004
# ..                       ...           ...            ...        ...
# 801  2007-02-16T00:00:00.000   41.89162851  -87.639040673       2007
# 804  2018-02-16T00:00:00.000  41.890072617  -87.635597856       2018
# 812  2018-02-16T00:00:00.000   41.89162851  -87.639040673       2018
# 823  2018-10-16T00:00:00.000           NaN            NaN       2018
# 831  2015-12-16T00:00:00.000  41.890798214   -87.64225168       2015
# 832  2013-09-16T00:00:00.000  41.892490235  -87.634759779       2013
# 834  2011-08-19T00:00:00.000  41.892490235  -87.634759779       2011
# 859  2011-04-15T00:00:00.000   41.89571223  -87.634325683       2011
# 864  2018-09-16T00:00:00.000           NaN            NaN       2018
# 871  2018-09-16T00:00:00.000  41.895673905  -87.636371674       2018
# 878  2018-09-16T00:00:00.000           NaN            NaN       2018
# 888  2018-09-16T00:00:00.000  41.888074281  -87.634955203       2018
# 889  2016-09-16T00:00:00.000  41.888074281  -87.634955203       2016
# 895  2018-09-16T00:00:00.000  41.892677998  -87.645807263       2018
# 904  2018-09-16T00:00:00.000   41.89038185  -87.634184835       2018
# 911  2003-05-16T00:00:00.000  41.893359354  -87.629845147       2003
# 913  2010-02-16T00:00:00.000  41.893359354  -87.629845147       2010
# 943  2004-05-16T00:00:00.000  41.893359354  -87.629845147       2004
# 947  2005-02-16T00:00:00.000  41.893359354  -87.629845147       2005
# 950  2004-05-16T00:00:00.000  41.893359354  -87.629845147       2004
# 958  2006-02-16T00:00:00.000  41.893359354  -87.629845147       2006
# 960  2008-02-16T00:00:00.000  41.893359354  -87.629845147       2008
# 963  2007-02-16T00:00:00.000  41.893359354  -87.629845147       2007
# 964  2010-02-16T00:00:00.000  41.893359354  -87.629845147       2010
# 977  2018-09-16T00:00:00.000   41.89462001   -87.63894329       2018
# 979  2018-09-16T00:00:00.000  41.888087353  -87.630888075       2018
# 981  2002-05-16T00:00:00.000  41.893359354  -87.629845147       2002
# 982  2007-02-16T00:00:00.000  41.893359354  -87.629845147       2007
# 992  2012-02-16T00:00:00.000  41.893359354  -87.629845147       2012
# 994  2006-02-16T00:00:00.000  41.893359354  -87.629845147       2006
#
# [1888 rows x 10 columns]

# %%
# Get rid of NaN values in 'latitude' and 'license_start_date'
core_info_busi_licences.dropna(subset=['latitude'], inplace=True)
core_info_busi_licences.dropna(subset=['license_start_date'], inplace=True)
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Cast 'start_year' column as an integer
core_info_busi_licences['start_year'] = core_info_busi_licences['start_year'].astype('int64')
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
core_info_busi_licences.isna().sum()

# %%
len(core_info_busi_licences)

# %% [markdown]
# ## Connect to sqlite database

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
from config2 import mysql_password

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Create engine using the `demographics.sqlite` database file
# engine = create_engine("sqlite://", echo=False)

engine = create_engine(f'mysql://root:coolcat1015@localhost:3306/real_tech_db')

# %%
# Copy 'core_info_busi_licenses' db to MySql database
core_info_busi_licences.to_sql('business_licenses', 
                               con=engine, 
                               if_exists='replace',
                               index_label=True)
