# %% [markdown]
# ## Connect to Chicago Data Portal API - Business Licenses Data

# %%
#Import dependencies
import pandas as pd
import requests
import json

# Google developer API key
from config2 import API_chi_key

# %%
# Build API URL
target_URL = f"https://data.cityofchicago.org/resource/xqx5-8hwx.json?$$app_token={API_chi_key}&zip_code="

# %%
# create list of zipcodes we are examining based
# on three different businesses of interest
zipcodes = ["60610","60607","60606","60661",
            "60614","60622","60647","60654"]

# %%
# Create a request to get json data on business licences
responses = []
for zipcode in zipcodes:
    license_response = requests.get(target_URL + zipcode).json()
    responses.append(license_response)

# %%
# Create sepearte variables for the 8 responses for zipcodes
# Data loaded in nested gropus based on zipcodes, so
# needed to make them separate
zip_60610 = responses[0]
zip_60607 = responses[1]
zip_60606 = responses[2]
zip_60661 = responses[3]
zip_60614 = responses[4]
zip_60622 = responses[5]
zip_60647 = responses[6]
zip_60654 = responses[7]

# %%
# Read zipcode_responses_busi.json files into pd DF
zip_60610_data = pd.DataFrame(zip_60610)

# %%
# Create list of the json object variables
# excluding zip_60610 bc that will start as a DF
zip_data = [zip_60607, zip_60606, zip_60661, zip_60614,
           zip_60622, zip_60647, zip_60654]

# %%
# Create a new DF to save compiled business data into
all_7_zipcodes = zip_60610_data

# %%
# Append json objects to all_7_zipcode DF
# Print length of all_7_zipcode to check adding correctly
for zipcodes_df in zip_data:
    all_7_zipcodes = all_7_zipcodes.append(zipcodes_df)
    print(len(all_7_zipcodes))
# Out:
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# C:\Users\oimar\Miniconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
# Get list of headers of all_7_zipcodes
list(all_7_zipcodes)
# Out:
# ['account_number',
#  'address',
#  'application_created_date',
#  'application_requirements_complete',
#  'application_type',
#  'business_activity',
#  'business_activity_id',
#  'city',
#  'conditional_approval',
#  'date_issued',
#  'doing_business_as_name',
#  'expiration_date',
#  'id',
#  'latitude',
#  'legal_name',
#  'license_approved_for_issuance',
#  'license_code',
#  'license_description',
#  'license_id',
#  'license_number',
#  'license_start_date',
#  'license_status',
#  'license_status_change_date',
#  'location',
#  'longitude',
#  'payment_date',
#  'police_district',
#  'precinct',
#  'site_number',
#  'ssa',
#  'state',
#  'ward',
#  'ward_precinct',
#  'zip_code']

# %%
# Select certain columns to show 
core_info_busi_licences = all_7_zipcodes[['legal_name', 'doing_business_as_name',
                                        'zip_code', 'license_description', 
                                        'business_activity', 'application_type', 
                                        'license_start_date', 'latitude', 'longitude']]

# %%
# Get an idea of the number of null values in each column
core_info_busi_licences.isna().sum()
# Out:
# legal_name                   0
# doing_business_as_name       0
# zip_code                     0
# license_description          0
# business_activity         1480
# application_type             0
# license_start_date          20
# latitude                   433
# longitude                  433
# dtype: int64

# %%
# Explore what kinds of businesses are missing "latitude" and "longitude"
# Also, the 'business_activity' licenses have null values (limited Business Licences?)
core_info_busi_licences[core_info_busi_licences.isnull().any(axis=1)]
# Out:
#                                      legal_name  \
# 15                           PAPER SOURCE, INC.
# 26            DAVE & BUSTER'S OF ILLINOIS, INC.
# 32            DAVE & BUSTER'S OF ILLINOIS, INC.
# 35            DAVE & BUSTER'S OF ILLINOIS, INC.
# 54            DAVE & BUSTER'S OF ILLINOIS, INC.
# 63            DAVE & BUSTER'S OF ILLINOIS, INC.
# 72            DAVE & BUSTER'S OF ILLINOIS, INC.
# 76            DAVE & BUSTER'S OF ILLINOIS, INC.
# 77            DAVE & BUSTER'S OF ILLINOIS, INC.
# 78                     H & S TRAVEL GROUP, INC.
# 83                                      RTP INC
# 86                                      RTP INC
# 87          CHICAGO FLY FISHING OUTFITTERS LTD.
# 93                                SOOK CHA CHOI
# 94                       JOEL OPPENHEIMER, INC.
# 124                           STUDIO BLUE, INC.
# 130                         1028 N RUSH ST CORP
# 136                             WAKENYA CHISLEY
# 137                              CASSIDY OBRIEN
# 138                        ELLIE VAN KEIRSBILCK
# 149                                PAMELA NOSSE
# 159            CHICAGO HEALTH ENTERPRISES, LTD.
# 188       FEDEX OFFICE AND PRINT SERVICES, INC.
# 189         CHESTNUT MARC VENTURE OPERATING LLC
# 190       FEDEX OFFICE AND PRINT SERVICES, INC.
# 191         CHESTNUT MARC VENTURE OPERATING LLC
# 193                          KCL FITNESS L.L.C.
# 227                                 RUBEN REYES
# 234  WEARY & BAITY INC. DBA THE UPS STORE #2872
# 243                          POTASH BROS., INC.
# ..                                          ...
# 701                          751 N. CLARK, INC.
# 707                          751 N. CLARK, INC.
# 708                          751 N. CLARK, INC.
# 711                          751 N. CLARK, INC.
# 712                          751 N. CLARK, INC.
# 845                           STAY ALFRED, INC.
# 897                               MARCHESA, LLC
# 900                               MARCHESA, LLC
# 901                               MARCHESA, LLC
# 907                           R. LATITUDE, INC.
# 908                           R. LATITUDE, INC.
# 909                           R. LATITUDE, INC.
# 910                           R. LATITUDE, INC.
# 912                           R. LATITUDE, INC.
# 913                           R. LATITUDE, INC.
# 914                           R. LATITUDE, INC.
# 916                           R. LATITUDE, INC.
# 918                           R. LATITUDE, INC.
# 919                           R. LATITUDE, INC.
# 920                           R. LATITUDE, INC.
# 922                           R. LATITUDE, INC.
# 951       BENCHMARK HOSPITALITY OF CHICAGO, LLC
# 957                                 TEKNION LLC
# 959                        SPOTVIEW CORPORATION
# 960                  The Power Company USA, LLC
# 962                  The Power Company USA, LLC
# 974                             CLEISE SPA INC.
# 979                        BRIGHT CHAIR COMPANY
# 994                            365 Outdoor, LLC
# 998                              PARKKING, INC.
#
#                                 doing_business_as_name zip_code  \
# 15                                    PAPER SOURCE INC    60610
# 26                                     DAVE & BUSTER'S    60610
# 32                                     DAVE & BUSTER'S    60610
# 35                                     DAVE & BUSTER'S    60610
# 54                                     DAVE & BUSTER'S    60610
# 63                                     DAVE & BUSTER'S    60610
# 72                                     DAVE & BUSTER'S    60610
# 76                                     DAVE & BUSTER'S    60610
# 77                                     DAVE & BUSTER'S    60610
# 78   FOREMOST TRAVEL & TOURS/TRAVELONI/WINDY CITY T...    60610
# 83                                            RTP INC.    60610
# 86                                            RTP INC.    60610
# 87                 CHICAGO FLY FISHING OUTFITTERS LTD.    60610
# 93                                       BEST CLEANERS    60610
# 94                               JOEL OPPENHEIMER, INC    60610
# 124                                        STUDIO BLUE    60610
# 130                                GIBSON'S STEAKHOUSE    60610
# 136                                    WAKENYA CHISLEY    60610
# 137                                     CASSIDY OBRIEN    60610
# 138                               ELLIE VAN KEIRSBILCK    60610
# 149                                       PAMELA NOSSE    60610
# 159                      CHICAGO HEALTH - MAPLE STREET    60610
# 188                  FEDEX OFFICE AND PRINT SVCS, INC.    60610
# 189                                   FIELDHOUSE JONES    60610
# 190                  FEDEX OFFICE AND PRINT SVCS, INC.    60610
# 191                                   FIELDHOUSE JONES    60610
# 193                              WELLS STREET CROSSFIT    60610
# 227                                        RUBEN REYES    60610
# 234                                THE UPS STORE #2872    60610
# 243                                    POTASH BROS INC    60610
# ..                                                 ...      ...
# 701                                  ROCKS RIVER NORTH    60654
# 707                                  ROCKS RIVER NORTH    60654
# 708                                  ROCKS RIVER NORTH    60654
# 711                                  ROCKS RIVER NORTH    60654
# 712                                  ROCKS RIVER NORTH    60654
# 845                                  STAY ALFRED, INC.    60654
# 897                                           MARCHESA    60654
# 900                                           MARCHESA    60654
# 901                                           MARCHESA    60654
# 907           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 908           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 909           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 910           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 912           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 913           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 914           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 916           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 918           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 919           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 920           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 922           PARLIAMENT/KENSINGTON ROOFTOP AND LOUNGE    60654
# 951              BENCHMARK HOSPITALITY OF CHICAGO, LLC    60654
# 957                                        TEKNION LLC    60654
# 959                                 PARAMOUNT CLEANERS    60654
# 960                                  The Power Company    60654
# 962                                  The Power Company    60654
# 974                           CLEISE BRAZILIAN DAY SPA    60654
# 979                               BRIGHT CHAIR COMPANY    60654
# 994                                   365 Outdoor, LLC    60654
# 998                                 ELITE PARKING INC.    60654
#
#                                license_description  \
# 15                        Limited Business License
# 26                        Limited Business License
# 32                        Limited Business License
# 35                        Limited Business License
# 54                        Limited Business License
# 63                        Limited Business License
# 72                        Limited Business License
# 76                        Limited Business License
# 77                        Limited Business License
# 78                        Limited Business License
# 83                        Limited Business License
# 86                        Limited Business License
# 87                        Limited Business License
# 93                        Limited Business License
# 94                        Limited Business License
# 124                       Limited Business License
# 130                       Limited Business License
# 136                  Pharmaceutical Representative
# 137                  Pharmaceutical Representative
# 138                  Pharmaceutical Representative
# 149                  Pharmaceutical Representative
# 159                       Limited Business License
# 188                       Limited Business License
# 189                      Retail Food Establishment
# 190                       Limited Business License
# 191                     Regulated Business License
# 193                     Regulated Business License
# 227                  Pharmaceutical Representative
# 234                       Limited Business License
# 243                       Limited Business License
# ..                                             ...
# 701                                Music and Dance
# 707                       Limited Business License
# 708                                Music and Dance
# 711                       Limited Business License
# 712                                Music and Dance
# 845                     Regulated Business License
# 897  Consumption on Premises - Incidental Activity
# 900                                        Tobacco
# 901                      Retail Food Establishment
# 907                                         Tavern
# 908                      Public Place of Amusement
# 909                      Public Place of Amusement
# 910                                         Tavern
# 912                                         Tavern
# 913                      Public Place of Amusement
# 914                      Public Place of Amusement
# 916                      Public Place of Amusement
# 918                                         Tavern
# 919                                         Tavern
# 920                                         Tavern
# 922                      Public Place of Amusement
# 951                       Limited Business License
# 957                       Limited Business License
# 959                       Limited Business License
# 960                       Limited Business License
# 962                       Limited Business License
# 974                       Limited Business License
# 979                       Limited Business License
# 994                       Limited Business License
# 998                              Commercial Garage
#
#                                      business_activity application_type  \
# 15                                                 NaN            RENEW
# 26                                                 NaN            RENEW
# 32                                                 NaN            RENEW
# 35                                                 NaN            RENEW
# 54                                                 NaN            RENEW
# 63                                                 NaN            RENEW
# 72                                                 NaN            RENEW
# 76                                                 NaN            RENEW
# 77                                                 NaN            RENEW
# 78                                                 NaN            ISSUE
# 83                                                 NaN            RENEW
# 86                                                 NaN            RENEW
# 87                                                 NaN            RENEW
# 93                                                 NaN            RENEW
# 94                                                 NaN            RENEW
# 124                                                NaN            RENEW
# 130                                                NaN            RENEW
# 136  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 137  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 138  Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 149  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 159                                                NaN            ISSUE
# 188                                                NaN            RENEW
# 189  Preparation of Food and Dining on Premise With...            RENEW
# 190                                                NaN            RENEW
# 191                   Hotel - 7 or More Sleeping Rooms            RENEW
# 193                                    Fitness Classes            RENEW
# 227  Markets / Promotes Pharmaceuticals to Health C...            RENEW
# 234                                                NaN            RENEW
# 243                                                NaN            RENEW
# ..                                                 ...              ...
# 701                                                NaN            RENEW
# 707                                                NaN            RENEW
# 708                                                NaN            RENEW
# 711                                                NaN            RENEW
# 712                                                NaN            RENEW
# 845  Vacation Rental Building Containing Five or Mo...            ISSUE
# 897                  Consumption of Liquor on Premises            ISSUE
# 900  Retail Sales of Tobacco and Flavored Tobacco P...            ISSUE
# 901  Preparation of Food and Dining on Premise With...            ISSUE
# 907          Tavern - Consumption of Liquor on Premise            RENEW
# 908         Provides Onsite Amusement or Entertainment            RENEW
# 909         Provides Onsite Amusement or Entertainment            RENEW
# 910          Tavern - Consumption of Liquor on Premise            ISSUE
# 912          Tavern - Consumption of Liquor on Premise            RENEW
# 913         Provides Onsite Amusement or Entertainment            RENEW
# 914         Provides Onsite Amusement or Entertainment            RENEW
# 916         Provides Onsite Amusement or Entertainment            RENEW
# 918          Tavern - Consumption of Liquor on Premise            RENEW
# 919          Tavern - Consumption of Liquor on Premise            RENEW
# 920          Tavern - Consumption of Liquor on Premise            RENEW
# 922         Provides Onsite Amusement or Entertainment            ISSUE
# 951                                                NaN            RENEW
# 957                                                NaN            RENEW
# 959                                                NaN            RENEW
# 960                                                NaN            RENEW
# 962                                                NaN            ISSUE
# 974                                                NaN            ISSUE
# 979                                                NaN            RENEW
# 994                                                NaN            RENEW
# 998                                                NaN            RENEW
#
#           license_start_date      latitude      longitude
# 15   2018-02-16T00:00:00.000  41.896692555  -87.635628437
# 26   2011-03-16T00:00:00.000  41.901531983  -87.631526068
# 32   2005-05-16T00:00:00.000  41.901531983  -87.631526068
# 35   2003-05-16T00:00:00.000  41.901531983  -87.631526068
# 54   2002-05-16T00:00:00.000  41.901531983  -87.631526068
# 63   2009-03-16T00:00:00.000  41.901531983  -87.631526068
# 72   2006-05-16T00:00:00.000  41.901531983  -87.631526068
# 76   2007-05-16T00:00:00.000  41.901531983  -87.631526068
# 77   2004-05-16T00:00:00.000  41.901531983  -87.631526068
# 78   2012-11-05T00:00:00.000  41.907401025   -87.63445142
# 83   2018-02-16T00:00:00.000  41.904860444  -87.640877188
# 86   2016-02-16T00:00:00.000  41.904860444  -87.640877188
# 87   2019-04-16T00:00:00.000  41.905391727  -87.641615883
# 93   2018-02-16T00:00:00.000  41.903761516  -87.633306964
# 94   2019-03-16T00:00:00.000  41.890156071  -87.629151995
# 124  2002-02-16T00:00:00.000  41.889949311  -87.628373571
# 130  2019-03-16T00:00:00.000  41.901867357  -87.628492145
# 136  2018-12-18T00:00:00.000           NaN            NaN
# 137  2019-01-28T00:00:00.000           NaN            NaN
# 138  2018-11-08T00:00:00.000           NaN            NaN
# 149  2019-02-16T00:00:00.000           NaN            NaN
# 159  2010-11-10T00:00:00.000  41.901982552  -87.629263103
# 188  2019-01-16T00:00:00.000  41.890526116  -87.634188858
# 189  2018-11-16T00:00:00.000           NaN            NaN
# 190  2019-01-16T00:00:00.000  41.904019547  -87.629841921
# 191  2018-11-16T00:00:00.000           NaN            NaN
# 193  2018-12-16T00:00:00.000           NaN            NaN
# 227  2019-01-16T00:00:00.000           NaN            NaN
# 234  2019-02-16T00:00:00.000  41.911013149  -87.638017712
# 243  2007-02-16T00:00:00.000  41.898878197  -87.628111148
# ..                       ...           ...            ...
# 701  2002-05-16T00:00:00.000  41.896406651  -87.631094811
# 707  2004-05-16T00:00:00.000  41.896406651  -87.631094811
# 708  2004-02-16T00:00:00.000  41.896406651  -87.631094811
# 711  2007-02-16T00:00:00.000  41.896406651  -87.631094811
# 712  2003-05-16T00:00:00.000  41.896406651  -87.631094811
# 845  2017-11-17T00:00:00.000           NaN            NaN
# 897  2017-11-28T00:00:00.000           NaN            NaN
# 900  2017-11-28T00:00:00.000           NaN            NaN
# 901  2017-11-28T00:00:00.000           NaN            NaN
# 907  2014-02-16T00:00:00.000           NaN            NaN
# 908  2014-02-16T00:00:00.000           NaN            NaN
# 909  2016-02-16T00:00:00.000           NaN            NaN
# 910  2007-07-05T00:00:00.000           NaN            NaN
# 912  2016-02-16T00:00:00.000           NaN            NaN
# 913  2012-02-16T00:00:00.000           NaN            NaN
# 914  2010-02-16T00:00:00.000           NaN            NaN
# 916  2008-02-16T00:00:00.000           NaN            NaN
# 918  2008-02-16T00:00:00.000           NaN            NaN
# 919  2012-02-16T00:00:00.000           NaN            NaN
# 920  2010-02-16T00:00:00.000           NaN            NaN
# 922  2007-09-05T00:00:00.000           NaN            NaN
# 951  2012-05-16T00:00:00.000           NaN            NaN
# 957  2018-05-16T00:00:00.000  41.888074281  -87.634955203
# 959  2015-12-16T00:00:00.000  41.890798214   -87.64225168
# 960  2013-09-16T00:00:00.000  41.892490235  -87.634759779
# 962  2011-08-19T00:00:00.000  41.892490235  -87.634759779
# 974  2011-04-15T00:00:00.000   41.89571223  -87.634325683
# 979  2018-05-16T00:00:00.000  41.888074281  -87.634955203
# 994  2018-12-16T00:00:00.000  41.894028669  -87.639836917
# 998  2007-08-16T00:00:00.000  41.890297758  -87.642784742
#
# [1839 rows x 9 columns]

# %%
# Get rid of NaN values in 'latitude' and 'license_start_date'
core_info_busi_licences.dropna(subset=['latitude'], inplace=True)
core_info_busi_licences.dropna(subset=['license_start_date'], inplace=True)
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
core_info_busi_licences.isna().sum()

# %%
len(core_info_busi_licences)

# %% [markdown]
# ## Connect to sqlite database

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
from config2 import mysql_password

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Create engine using the `demographics.sqlite` database file
# engine = create_engine("sqlite://", echo=False)

engine = create_engine(f'mysql://root:coolcat1015@localhost:3306/real_tech_db')

# %%
# Copy 'core_info_busi_licenses' db to MySql database
core_info_busi_licences.to_sql('business_licenses', 
                               con=engine, 
                               if_exists='replace',
                               index_label=True)
