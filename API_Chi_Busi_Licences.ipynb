# %% [markdown]
# ## Connect to Chicago Data Portal API - Business Licenses Data

# %%
#Import dependencies
import pandas as pd
import requests
import json

# Google developer API key
from config2 import API_chi_key

# %%
# Build API URL
# API calls = 8000 (based on zipcode and issued search results)
# Filters: 'application type' Issued
target_URL = f"https://data.cityofchicago.org/resource/xqx5-8hwx.json?$$app_token={API_chi_key}&$limit=8000&application_type=ISSUE&zip_code="

# %%
# Create list of zipcodes we are examining based
# on three different businesses of interest
zipcodes = ["60610","60607","60606","60661",
            "60614","60622","60647","60654"]

# %%
# Create a request to get json data on business licences
responses = []
for zipcode in zipcodes:
    license_response = requests.get(target_URL + zipcode).json()
    responses.append(license_response)

# %%
len(responses)
# Out:
# 8

# %%
# Create sepearte variables for the 8 responses for zipcodes
# Data loaded in nested gropus based on zipcodes, so
# needed to make them separate
zip_60610 = responses[0]
zip_60607 = responses[1]
zip_60606 = responses[2]
zip_60661 = responses[3]
zip_60614 = responses[4]
zip_60622 = responses[5]
zip_60647 = responses[6]
zip_60654 = responses[7]

# %%
# Read zipcode_responses_busi.json files into pd DF
zip_60610_data = pd.DataFrame(zip_60610)

# %%
# Create list of the json object variables
# excluding zip_60610 bc that will start as a DF
zip_data = [zip_60607, zip_60606, zip_60661, zip_60614,
           zip_60622, zip_60647, zip_60654]

# %%
# Create a new DF to save compiled business data into
all_7_zipcodes = zip_60610_data

# %%
# Append json objects to all_7_zipcode DF
# Print length of all_7_zipcode to check adding correctly
for zipcodes_df in zip_data:
    all_7_zipcodes = all_7_zipcodes.append(zipcodes_df)
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
len(all_7_zipcodes)
# Out:
# 37679

# %%
# Get list of headers of all_7_zipcodes
list(all_7_zipcodes)
# Out:
# ['account_number',
#  'address',
#  'application_created_date',
#  'application_requirements_complete',
#  'application_type',
#  'business_activity',
#  'business_activity_id',
#  'city',
#  'conditional_approval',
#  'date_issued',
#  'doing_business_as_name',
#  'expiration_date',
#  'id',
#  'latitude',
#  'legal_name',
#  'license_approved_for_issuance',
#  'license_code',
#  'license_description',
#  'license_id',
#  'license_number',
#  'license_start_date',
#  'license_status',
#  'license_status_change_date',
#  'location',
#  'longitude',
#  'payment_date',
#  'police_district',
#  'precinct',
#  'site_number',
#  'ssa',
#  'state',
#  'ward',
#  'ward_precinct',
#  'zip_code']

# %%
# Select certain columns to show 
core_info_busi_licences = all_7_zipcodes[['legal_name', 'doing_business_as_name',
                                        'zip_code', 'license_description', 
                                        'business_activity', 'application_type', 
                                        'license_start_date', 'latitude', 'longitude']]

# %%
# Get an idea of the number of null values in each column
core_info_busi_licences.isna().sum()
# Out:
# legal_name                    0
# doing_business_as_name        0
# zip_code                      0
# license_description           0
# business_activity         15953
# application_type              0
# license_start_date          519
# latitude                    622
# longitude                   622
# dtype: int64

# %%
# Add sepearate column for just the start year
# Will use later when selecting year businesess were created
core_info_busi_licences['start_year'] = core_info_busi_licences['license_start_date']
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Edit 'start_year' to just include year from date information
core_info_busi_licences['start_year'] = core_info_busi_licences['start_year'].str[0:4]
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Explore what kinds of businesses are missing "latitude" and "longitude"
# Also, the 'business_activity' licenses have null values (limited Business Licences?)
core_info_busi_licences[core_info_busi_licences.isnull().any(axis=1)]
# Out:
#                                         legal_name  \
# 16              HEAVENLY DAY SPA ON DIVISION, INC.
# 17    YOUNG MEN'S CHRISTIAN ASSOCIATION OF CHICAGO
# 18                            ALLYU 600 WEST, INC.
# 19                            4301 N Sheridan, LLC
# 20                         MARWEN FOUNDATION, INC.
# 21                                FLIGHT 001, INC.
# 22                     christine noelle design inc
# 25                         ARETE & ASSOCIATES, LLC
# 26                     DOWNTOWN ENTERTAINMENT, LLC
# 28                    TRATTORIA PIZZERIA ROMA INC.
# 29                     DOWNTOWN ENTERTAINMENT, LLC
# 30                     DOWNTOWN ENTERTAINMENT, LLC
# 31                              KCL FITNESS L.L.C.
# 32                     DOWNTOWN ENTERTAINMENT, LLC
# 33                            THE SONO CHICAGO LLC
# 34                    ELIZABETH GREGORY SERRITELLA
# 35                    CENTRAL PARKING SYSTEM, INC.
# 36              HEAVENLY DAY SPA ON DIVISION, INC.
# 37    YOUNG MEN'S CHRISTIAN ASSOCIATION OF CHICAGO
# 38                         MARWEN FOUNDATION, INC.
# 39                   WASHINGTON SQUARE LIQUORS INC
# 40                                  SALLY J. BAKER
# 41                            ALLYU 600 WEST, INC.
# 42                    TRATTORIA PIZZERIA ROMA INC.
# 83                                      JULIE EIDE
# 84                                 KIMBERLY D'ANNA
# 91                                   NICOLE RAUFER
# 98                                    LANA MERIDEN
# 99                                 KATHERINE MAHON
# 100                              ELIZABETH ROYSTON
# ...                                            ...
# 3479                           NO LIMIT AGENCY LLC
# 3480                DAILY PLANET PRODUCTIONS, LTD.
# 3482                COMCAST SPORTSNET CHICAGO, LLC
# 3484                                 LUNA TEXTILES
# 3486                      Silk Road Technology Inc
# 3488                             TS STAFFING CORP.
# 3489                          BLOSSOM BUCKET, INC.
# 3499                              YOGA FUZION, LLC
# 3500                                 Studio KL LLC
# 3504                            URBAN MENSWEAR LLC
# 3506                           IVYSTONE GROUP INC.
# 3509                                  HEHMEYER LLC
# 3512                   SUB-ZERO GROUP MIDWEST, LLC
# 3517                            MILSON & LOUIS INC
# 3519                         RIVER WEST BRANDS LLC
# 3521                           Farrow & Ball, Inc.
# 3522                          EDELMAN LEATHER, LLC
# 3523                               TLD chicago LLC
# 3527          PANGAEA INFORMATION TECHNOLOGIES LTD
# 3528                     E. A. Barin Flowers, Inc.
# 3534                JANUS ET CIE OF ILLINOIS, INC.
# 3540                    THREE FRIENDS STUDIO, LTD.
# 3541          STEPHEN W. MIRKIN & ASSOCIATES, INC.
# 3542                         WINWARD INTERNATIONAL
# 3544                         REMITSTREAM SOLUTIONS
# 3545                CALIFORNIA FLORAL IMPORTS INC.
# 3549                         PEKING HANDICRAFT INC
# 3551                         APD ENTERPRISES, INC.
# 3552                        D. W. SPECIALTIES INC.
# 3553                         THOMPSON'S CANDLE CO.
#
#                             doing_business_as_name zip_code  \
# 16                                      HM DAY SPA    60610
# 17    YOUNG MEN'S CHRISTIAN ASSOCIATION OF CHICAGO    60610
# 18                                       ALLYU SPA    60610
# 19                            4301 N Sheridan, LLC    60610
# 20                                          MARWEN    60610
# 21                                 FLIGHT 001, INC    60610
# 22                         Christine Noelle Design    60610
# 25                               FLORSHEIM MANSION    60610
# 26                                  HQ BEERCADE II    60610
# 28                                   WOODIE'S FLAT    60610
# 29                                  HQ BEERCADE II    60610
# 30                                  HQ BEERCADE II    60610
# 31                           WELLS STREET CROSSFIT    60610
# 32                                  HQ BEERCADE II    60610
# 33                            THE SONO CHICAGO LLC    60610
# 34                OLD TOWN CHICAGO BED & BREAKFAST    60610
# 35                                     CPS PARKING    60610
# 36                                      HM DAY SPA    60610
# 37    YOUNG MEN'S CHRISTIAN ASSOCIATION OF CHICAGO    60610
# 38                                          MARWEN    60610
# 39                                        BOSS BAR    60610
# 40                    GOLD COAST GUEST HOUSE B & B    60610
# 41                                       ALLYU SPA    60610
# 42                                   WOODIE'S FLAT    60610
# 83                                      JULIE EIDE    60610
# 84                                 KIMBERLY D'ANNA    60610
# 91                                   NICOLE RAUFER    60610
# 98                                    LANA MERIDEN    60610
# 99                                 KATHERINE MAHON    60610
# 100                              ELIZABETH ROYSTON    60610
# ...                                            ...      ...
# 3479                NO LIMIT MEDIA CONSULTING, LLC    60654
# 3480                DAILY PLANET PRODUCTIONS, LTD.    60654
# 3482                COMCAST SPORTSNET CHICAGO, LLC    60654
# 3484                                 LUNA TEXTILES    60654
# 3486                       SilkRoad Technology Inc    60654
# 3488                          TRI - STATE STAFFING    60654
# 3489                          BLOSSOM BUCKET, INC.    60654
# 3499                              YOGA FUZION, LLC    60654
# 3500                                 Studio KL LLC    60654
# 3504                                      ROCAWEAR    60654
# 3506                                IVYSTONE GROUP    60654
# 3509                     HTG CAPITAL PARTNERS, LLC    60654
# 3512                        SUB-ZERO WOLF SHOWROOM    60654
# 3517                       NOYMER LEATHER AND GIFT    60654
# 3519                         River West Brands LLC    60654
# 3521                           Farrow & Ball, Inc.    60654
# 3522                          EDELMAN LEATHER, LLC    60654
# 3523                         Real Ryder Revolution    60654
# 3527                      PANGAEA INFORMATION TECH    60654
# 3528                            BLOOMS AT THE MART    60654
# 3534                JANUS ET CIE OF ILLINOIS, INC.    60654
# 3540                    THREE FRIENDS STUDIO, LTD.    60654
# 3541          STEPHEN W. MIRKIN & ASSOCIATES, INC.    60654
# 3542                         WINWARD INTERNATIONAL    60654
# 3544                        REMITSTREAM SOLUTIONS.    60654
# 3545                CALIFORNIA FLORAL IMPORTS INC.    60654
# 3549                         PEKING HANDICRAFT INC    60654
# 3551                                  SNAP FITNESS    60654
# 3552                        D. W. SPECIALTIES INC.    60654
# 3553                         THOMPSON'S CANDLE CO.    60654
#
#                        license_description  \
# 16                Limited Business License
# 17                Limited Business License
# 18                Limited Business License
# 19       Residential Real Estate Developer
# 20        Children's Activities Facilities
# 21                Limited Business License
# 22                Limited Business License
# 25              Regulated Business License
# 26               Retail Food Establishment
# 28                           Outdoor Patio
# 29                Caterer's Liquor License
# 30               Public Place of Amusement
# 31              Regulated Business License
# 32                                  Tavern
# 33              Regulated Business License
# 34              Regulated Business License
# 35                        Accessory Garage
# 36                   Massage Establishment
# 37                                 Raffles
# 38    Children's Services Facility License
# 39               Public Place of Amusement
# 40              Regulated Business License
# 41                   Massage Establishment
# 42               Public Place of Amusement
# 83           Pharmaceutical Representative
# 84           Pharmaceutical Representative
# 91           Pharmaceutical Representative
# 98           Pharmaceutical Representative
# 99           Pharmaceutical Representative
# 100          Pharmaceutical Representative
# ...                                    ...
# 3479              Limited Business License
# 3480              Limited Business License
# 3482              Limited Business License
# 3484              Limited Business License
# 3486              Limited Business License
# 3488              Limited Business License
# 3489              Limited Business License
# 3499              Limited Business License
# 3500              Limited Business License
# 3504              Limited Business License
# 3506              Limited Business License
# 3509              Limited Business License
# 3512              Limited Business License
# 3517              Limited Business License
# 3519              Limited Business License
# 3521              Limited Business License
# 3522              Limited Business License
# 3523              Limited Business License
# 3527              Limited Business License
# 3528              Limited Business License
# 3534              Limited Business License
# 3540              Limited Business License
# 3541              Limited Business License
# 3542              Limited Business License
# 3544              Limited Business License
# 3545              Limited Business License
# 3549              Limited Business License
# 3551              Limited Business License
# 3552              Limited Business License
# 3553              Limited Business License
#
#                                       business_activity application_type  \
# 16                                                  NaN            ISSUE
# 17                                                  NaN            ISSUE
# 18                                                  NaN            ISSUE
# 19                                                  NaN            ISSUE
# 20                                                  NaN            ISSUE
# 21                                                  NaN            ISSUE
# 22                  Retail Sales of General Merchandise            ISSUE
# 25    Bed and Breakfast Establishment, Owner-Occupie...            ISSUE
# 26                     Retail Sales of Perishable Foods            ISSUE
# 28          Sale of Liquor Outdoors on Private Property            ISSUE
# 29                         Catering of Liquor To Events            ISSUE
# 30           Provides Onsite Amusement or Entertainment            ISSUE
# 31                                      Fitness Classes            ISSUE
# 32            Tavern - Consumption of Liquor on Premise            ISSUE
# 33    Bed and Breakfast Establishment, Owner-Occupie...            ISSUE
# 34    Bed and Breakfast Establishment, Owner-Occupie...            ISSUE
# 35    Provide Parking Spaces For a Fee - to Resident...            ISSUE
# 36                                Massage Establishment            ISSUE
# 37    Not-For-Profit Selling Raffles for Prizes of $...            ISSUE
# 38                     Children's Activities Facilities            ISSUE
# 39           Provides Onsite Amusement or Entertainment            ISSUE
# 40    Bed and Breakfast Establishment, Owner-Occupie...            ISSUE
# 41                                Massage Establishment            ISSUE
# 42    Public Place of Amusement, Provides Entertainm...            ISSUE
# 83    Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 84    Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 91    Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 98    Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 99    Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# 100   Markets / Promotes Pharmaceuticals to Health C...            ISSUE
# ...                                                 ...              ...
# 3479                                                NaN            ISSUE
# 3480                                                NaN            ISSUE
# 3482                                                NaN            ISSUE
# 3484                                                NaN            ISSUE
# 3486                                                NaN            ISSUE
# 3488                                                NaN            ISSUE
# 3489                                                NaN            ISSUE
# 3499                                                NaN            ISSUE
# 3500                                                NaN            ISSUE
# 3504                                                NaN            ISSUE
# 3506                                                NaN            ISSUE
# 3509                                                NaN            ISSUE
# 3512                                                NaN            ISSUE
# 3517                                                NaN            ISSUE
# 3519                                                NaN            ISSUE
# 3521                                                NaN            ISSUE
# 3522                                                NaN            ISSUE
# 3523                                                NaN            ISSUE
# 3527                                                NaN            ISSUE
# 3528                                                NaN            ISSUE
# 3534                                                NaN            ISSUE
# 3540                                                NaN            ISSUE
# 3541                                                NaN            ISSUE
# 3542                                                NaN            ISSUE
# 3544                                                NaN            ISSUE
# 3545                                                NaN            ISSUE
# 3549                                                NaN            ISSUE
# 3551                                                NaN            ISSUE
# 3552                                                NaN            ISSUE
# 3553                                                NaN            ISSUE
#
#            license_start_date      latitude      longitude start_year
# 16    2009-12-10T00:00:00.000           NaN            NaN       2009
# 17    2006-04-06T00:00:00.000           NaN            NaN       2006
# 18    2007-08-23T00:00:00.000           NaN            NaN       2007
# 19    2004-08-20T00:00:00.000           NaN            NaN       2004
# 20    2012-04-06T00:00:00.000           NaN            NaN       2012
# 21    2008-05-22T00:00:00.000           NaN            NaN       2008
# 22    2013-07-22T00:00:00.000           NaN            NaN       2013
# 25    2014-05-02T00:00:00.000           NaN            NaN       2014
# 26    2005-03-16T00:00:00.000           NaN            NaN       2005
# 28    2015-03-26T00:00:00.000           NaN            NaN       2015
# 29    2015-06-10T00:00:00.000           NaN            NaN       2015
# 30    2005-07-22T00:00:00.000           NaN            NaN       2005
# 31    2014-11-20T00:00:00.000           NaN            NaN       2014
# 32    2005-07-22T00:00:00.000           NaN            NaN       2005
# 33    2016-04-21T00:00:00.000           NaN            NaN       2016
# 34    2012-12-29T00:00:00.000           NaN            NaN       2012
# 35    2011-02-24T00:00:00.000           NaN            NaN       2011
# 36    2009-12-22T00:00:00.000           NaN            NaN       2009
# 37    2003-03-12T00:00:00.000           NaN            NaN       2003
# 38    2012-12-29T00:00:00.000           NaN            NaN       2012
# 39    2011-04-07T00:00:00.000           NaN            NaN       2011
# 40    2012-12-29T00:00:00.000           NaN            NaN       2012
# 41    2007-11-02T00:00:00.000           NaN            NaN       2007
# 42    2015-03-26T00:00:00.000           NaN            NaN       2015
# 83    2017-08-11T00:00:00.000           NaN            NaN       2017
# 84    2017-08-11T00:00:00.000           NaN            NaN       2017
# 91    2017-08-14T00:00:00.000           NaN            NaN       2017
# 98    2017-08-25T00:00:00.000           NaN            NaN       2017
# 99    2017-08-29T00:00:00.000           NaN            NaN       2017
# 100   2017-08-30T00:00:00.000           NaN            NaN       2017
# ...                       ...           ...            ...        ...
# 3479  2012-05-03T00:00:00.000  41.895622836  -87.635824997       2012
# 3480  2010-08-24T00:00:00.000  41.895532419  -87.635825826       2010
# 3482  2004-11-19T00:00:00.000  41.888741038  -87.637080541       2004
# 3484  2003-03-25T00:00:00.000  41.888074281  -87.634955203       2003
# 3486  2010-11-08T00:00:00.000  41.889352033   -87.62884885       2010
# 3488  2009-05-27T00:00:00.000  41.896534314  -87.646163439       2009
# 3489  2009-07-14T00:00:00.000  41.888074281  -87.634955203       2009
# 3499  2012-07-24T00:00:00.000  41.890124973  -87.631509262       2012
# 3500  2012-10-16T00:00:00.000  41.890486055  -87.637148739       2012
# 3504  2003-05-07T00:00:00.000  41.888741038  -87.637080541       2003
# 3506  2008-05-12T00:00:00.000  41.888074281  -87.634955203       2008
# 3509  2008-08-08T00:00:00.000  41.896585191  -87.642996182       2008
# 3512  2010-11-10T00:00:00.000  41.888074281  -87.634955203       2010
# 3517  2003-05-08T00:00:00.000  41.888074281  -87.634955203       2003
# 3519  2014-08-25T00:00:00.000   41.88752864  -87.632646837       2014
# 3521  2008-02-06T00:00:00.000  41.888074281  -87.634955203       2008
# 3522  2009-04-20T00:00:00.000  41.888074281  -87.634955203       2009
# 3523  2011-12-05T00:00:00.000  41.890124973  -87.631509262       2011
# 3527  2006-05-05T00:00:00.000  41.896473425  -87.635030123       2006
# 3528  2008-02-08T00:00:00.000  41.888074281  -87.634955203       2008
# 3534  2008-07-30T00:00:00.000  41.888074281  -87.634955203       2008
# 3540  2008-04-07T00:00:00.000  41.888074281  -87.634955203       2008
# 3541  2008-02-21T00:00:00.000  41.888741038  -87.637080541       2008
# 3542  2003-03-31T00:00:00.000  41.888074281  -87.634955203       2003
# 3544  2003-04-25T00:00:00.000  41.888741038  -87.637080541       2003
# 3545  2003-04-24T00:00:00.000  41.888074281  -87.634955203       2003
# 3549  2004-05-18T00:00:00.000  41.888074281  -87.634955203       2004
# 3551  2011-04-06T00:00:00.000  41.894502778  -87.631343259       2011
# 3552  2006-10-26T00:00:00.000  41.888074281  -87.634955203       2006
# 3553  2008-04-21T00:00:00.000  41.888074281  -87.634955203       2008
#
# [16896 rows x 10 columns]

# %%
# Get rid of NaN values in 'latitude' and 'license_start_date'
core_info_busi_licences.dropna(subset=['latitude'], inplace=True)
core_info_busi_licences.dropna(subset=['license_start_date'], inplace=True)
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
core_info_busi_licences['application_type'].unique()
# Out:
# array(['ISSUE'], dtype=object)

# %%
# Cast 'start_year' column as an integer
core_info_busi_licences['start_year'] = core_info_busi_licences['start_year'].astype('int64')
# Out:
# C:\Users\oimar\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Confirm that NaN values for 'latitude' and 'license_start_date' 
# were dropped
core_info_busi_licences.isna().sum()
# Out:
# legal_name                    0
# doing_business_as_name        0
# zip_code                      0
# license_description           0
# business_activity         15758
# application_type              0
# license_start_date            0
# latitude                      0
# longitude                     0
# start_year                    0
# dtype: int64

# %%
# Record number of businesses licenses pulled 
len(core_info_busi_licences)
# Out:
# 36541

# %% [markdown]
# ## Connect to sqlite database

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
from config2 import mysql_password

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Create engine using the `demographics.sqlite` database file
# engine = create_engine("sqlite://", echo=False)

engine = create_engine(f'mysql://root:coolcat1015@localhost:3306/real_tech_db')

# %%
# Copy 'core_info_busi_licenses' db to MySql database
core_info_busi_licences.to_sql('business_licenses', 
                               con=engine, 
                               if_exists='replace',
                               index_label=True)
